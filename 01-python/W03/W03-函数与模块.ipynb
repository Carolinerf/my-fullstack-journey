# %%
def is_even(n):
    return n % 2 == 0
print(is_even(1))
print(is_even(2))
# Out:
# False
# True

# %%
def divide(a, b):
    """两数相除
    Args:
        a: 被除数
        b: 除数（不能为 0）
    Returns:
        商，类型 float
    """
    return a / b
print(divide.__doc__)
help(divide)
# Out:
# 两数相除
#     Args:
#         a: 被除数
#         b: 除数（不能为 0）
#     Returns:
#         商，类型 float
#
# Help on function divide in module __main__:
#
# divide(a, b)
#     两数相除
#     Args:
#         a: 被除数
#         b: 除数（不能为 0）
#     Returns:
#         商，类型 float
